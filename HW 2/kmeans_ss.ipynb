# %%
# %load kmeans.py
## Initialisation
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import copy

colmap = {1: 'r', 2: 'g', 3: 'b', 4: 'c', 5: 'm', 6: 'y'}
df = pd.read_csv('data_noah.csv', usecols=['spin', 'speed'])
df['color'] = np.full((len(df), 1), 'k')

plotx_min = min(df['spin']) - 1
plotx_max = max(df['spin']) + 1
ploty_min = min(df['speed']) - 1
ploty_max = max(df['speed']) + 1

# %%
def draw_plot():
    plt.figure(figsize=(5, 5))
    plt.scatter(df['spin'], df['speed'], color=df['color'], alpha=0.5, edgecolor='k')
    for i in centroids.keys():
        plt.scatter(*centroids[i], color=colmap[i])
    plt.xlabel('spin')
    plt.ylabel('speed')
    plt.xlim(plotx_min, plotx_max)
    plt.ylim(ploty_min, ploty_max)
    plt.show()

# %%
## Assignment Stage
def assignment(df, centroids):
    for i in centroids.keys():
        # sqrt((x1 - x2)^2 - (y1 - y2)^2)
        df['distance_from_{}'.format(i)] = (
            np.sqrt(
                (df['spin'] - centroids[i][0]) ** 2
             + (df['speed'] - centroids[i][1]) ** 2
            )
        )
    centroid_distance_cols = ['distance_from_{}'.format(i) for i in centroids.keys()]
    df['closest'] = df.loc[:, centroid_distance_cols].idxmin(axis=1)
    df['closest'] = df['closest'].map(lambda x: int(x.lstrip('distance_from_')))
    df['color'] = df['closest'].map(lambda x: colmap[x])
    return df

# %%
## Update Stage
def update(k):
    for i in centroids.keys():
        centroids[i][0] = np.mean(df[df['closest'] == i]['spin'])
        centroids[i][1] = np.mean(df[df['closest'] == i]['speed'])
    return k

# %%
# draw update arrows
# fig = plt.figure(figsize=(5, 5))
# plt.scatter(df['x'], df['y'], color=df['color'], alpha=0.5, edgecolor='k')
# for i in centroids.keys():
#     plt.scatter(*centroids[i], color=colmap[i])
# plt.xlim(plotx_min, plotx_max)
# plt.ylim(ploty_min, ploty_max)

# ax = plt.axes()
# for i in old_centroids.keys():
#     old_x = old_centroids[i][0]
#     old_y = old_centroids[i][1]
#     dx = (centroids[i][0] - old_centroids[i][0]) * 0.75
#     dy = (centroids[i][1] - old_centroids[i][1]) * 0.75
#     ax.arrow(old_x, old_y, dx, dy, head_width=2, head_length=3, fc=colmap[i], ec=colmap[i])
# plt.show()

# %%
# cost function
def cost_func():
    err = 0;
    for i in range(len(df)):
        j = df['closest'][i]
        err = err + df['distance_from_{}'.format(j)][i]
    return err

# %%
sumerr = [] 
K = 4
for k in range(1, K):
    centroids = { i+1: [df['spin'][entry], df['speed'][entry]] for i, entry in enumerate(random.sample(range(len(df)), k)) }
#     old_centroids = copy.copy(centroids)
    df = assignment(df, centroids)
    
    while True:
        closest_centroids = df['closest'].copy(deep=True)
        centroids = update(centroids)
        df = assignment(df, centroids)
        if closest_centroids.equals(df['closest']): break
    
    draw_plot()
    sumerr.append(cost_func())
    
print(sumerr)
plt.plot(list(i for i in range(1, K)), sumerr)
plt.xlabel('number of clusters')
plt.ylabel('sum of error')
plt.xlim(0, K)
plt.show()
# Out:
# [63295.535854664806, 20446.83523071507, 13407.451940249268]

# %%
from sklearn.metrics import confusion_matrix

pitch = pd.read_csv('data_noah.csv', usecols=['pitch_type'])
x = len(np.unique(pitch))
label = np.append(np.unique(pitch), np.unique(df['color']))
cfmx = pd.DataFrame(confusion_matrix(pitch, df['color']), index=label, columns= label)
cfmx = cfmx.iloc[:x, x:]
print(np.unique(pitch), np.unique(df['color']))

col = {'r': 'red', 'g': 'green', 'b': 'blue', 'c': 'cyan', 'm': 'magenta', 'y': 'yellow'}
def func(s):
    return ['background-color: {}; opacity: 0.6'.format(col[s.name])]*len(s)

cfmx.style.apply(func, axis=0)
# Out:
# ['CH' 'CU' 'FF'] ['b' 'g' 'r']
# <style  type="text/css" >
#     #T_eb4a2ccc_e1be_11e8_a15c_a8667f02e89crow0_col0 {
#             background-color:  blue;
#              opacity:  0.6;
#         }    #T_eb4a2ccc_e1be_11e8_a15c_a8667f02e89crow0_col1 {
#             background-color:  green;
#              opacity:  0.6;
#         }    #T_eb4a2ccc_e1be_11e8_a15c_a8667f02e89crow0_col2 {
#             background-color:  red;
#              opacity:  0.6;
#         }    #T_eb4a2ccc_e1be_11e8_a15c_a8667f02e89crow1_col0 {
#             background-color:  blue;
#              opacity:  0.6;
#         }    #T_eb4a2ccc_e1be_11e8_a15c_a8667f02e89crow1_col1 {
#             background-color:  green;
#              opacity:  0.6;
#         }    #T_eb4a2ccc_e1be_11e8_a15c_a8667f02e89crow1_col2 {
#             background-color:  red;
#              opacity:  0.6;
#         }    #T_eb4a2ccc_e1be_11e8_a15c_a8667f02e89crow2_col0 {
#             background-color:  blue;
#              opacity:  0.6;
#         }    #T_eb4a2ccc_e1be_11e8_a15c_a8667f02e89crow2_col1 {
#             background-color:  green;
#              opacity:  0.6;
#         }    #T_eb4a2ccc_e1be_11e8_a15c_a8667f02e89crow2_col2 {
#             background-color:  red;
#              opacity:  0.6;
#         }</style>
# <table id="T_eb4a2ccc_e1be_11e8_a15c_a8667f02e89c" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >b</th>
#         <th class="col_heading level0 col1" >g</th>
#         <th class="col_heading level0 col2" >r</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_eb4a2ccc_e1be_11e8_a15c_a8667f02e89clevel0_row0" class="row_heading level0 row0" >CH</th>
#         <td id="T_eb4a2ccc_e1be_11e8_a15c_a8667f02e89crow0_col0" class="data row0 col0" >1</td>
#         <td id="T_eb4a2ccc_e1be_11e8_a15c_a8667f02e89crow0_col1" class="data row0 col1" >161</td>
#         <td id="T_eb4a2ccc_e1be_11e8_a15c_a8667f02e89crow0_col2" class="data row0 col2" >0</td>
#     </tr>    <tr>
#         <th id="T_eb4a2ccc_e1be_11e8_a15c_a8667f02e89clevel0_row1" class="row_heading level0 row1" >CU</th>
#         <td id="T_eb4a2ccc_e1be_11e8_a15c_a8667f02e89crow1_col0" class="data row1 col0" >0</td>
#         <td id="T_eb4a2ccc_e1be_11e8_a15c_a8667f02e89crow1_col1" class="data row1 col1" >0</td>
#         <td id="T_eb4a2ccc_e1be_11e8_a15c_a8667f02e89crow1_col2" class="data row1 col2" >301</td>
#     </tr>    <tr>
#         <th id="T_eb4a2ccc_e1be_11e8_a15c_a8667f02e89clevel0_row2" class="row_heading level0 row2" >FF</th>
#         <td id="T_eb4a2ccc_e1be_11e8_a15c_a8667f02e89crow2_col0" class="data row2 col0" >599</td>
#         <td id="T_eb4a2ccc_e1be_11e8_a15c_a8667f02e89crow2_col1" class="data row2 col1" >259</td>
#         <td id="T_eb4a2ccc_e1be_11e8_a15c_a8667f02e89crow2_col2" class="data row2 col2" >0</td>
#     </tr></tbody>
# </table>
